# %%
import ipaddress
a4 = ipaddress.ip_address('192.168.0.1') # 사설주소 192.~~로 시작
a6 = ipaddress.ip_address('2001:db8::1')

print(int(a4))
print(int(a6))
print(str(a4))
print(str(a6))

a4.is_loopback
# Out:
# 3232235521
# 42540766411282592856903984951653826561
# 192.168.0.1
# 2001:db8::1
# False
