# %% [markdown]
# ## time_ client, server 결과 화면
#
# [![image.png](attachment:image.png)] [![image-2.png](attachment:image-2.png)]

# %% [markdown]
# ## echo_clinet, server
#
# [![image.png](attachment:image.png)]
# [![image-2.png](attachment:image-2.png)]

# %% [markdown]
# ## number_client, server
#
# [![image.png](attachment:image.png)] [![image-2.png](attachment:image-2.png)]
